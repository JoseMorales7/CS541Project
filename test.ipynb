# %%
import CitiesData
import matplotlib.pyplot as plt

# %%
trainDataLoader, testDataLoader = CitiesData.getCitiesDataLoader("./Data/")

# %%
for p in trainDataLoader:
    image, city, long, lat = p
    break

# %%
print(city[0])
print("{},{}".format(long[0], lat[0]))
plt.imshow(image[0])
# Out:
# LosAngeles
# 34.15462940989372,-118.41161423844716

# %%
for p in testDataLoader:
    image, city, long, lat = p
    break

# %%
print(city[0])
print("{},{}".format(long[0], lat[0]))
plt.imshow(image[0])
# Out:
# Seattle
# 47.57403595534356,-122.30396949511703
